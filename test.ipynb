# %%
import requests
import pandas
import numpy
import json

#import modules

# %%
r=requests.get(f'https://api.fda.gov/food/enforcement.json?search=distribution_pattern:"nationwide"+AND+status:"Ongoing"+AND+(classification:"Class II"+classification:"Class I")&limit=10')

# %%
if(r.status_code==200):
   recallData=r.json()
   with open('food_recall_data.json', 'w') as json_file:
        json.dump(recallData, json_file, indent=4)

else: 
   print(f"ERROR: RESPONSE CODE{r.status_code}")

# %%
import requests

# Define the URL
url = 'https://api.fda.gov/drug/event.json?search=patient.reaction.reactionmeddrapt:"fatigue"+AND+occurcountry:"ca"&limit=1'

# Make the GET request
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the response as JSON
    data = response.json()
    print(data)
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.', 'terms': 'https://open.fda.gov/terms/', 'license': 'https://open.fda.gov/license/', 'last_updated': '2024-07-30', 'results': {'skip': 0, 'limit': 1, 'total': 53084}}, 'results': [{'safetyreportversion': '7', 'safetyreportid': '10005435', 'primarysourcecountry': 'CA', 'occurcountry': 'CA', 'transmissiondateformat': '102', 'transmissiondate': '20141212', 'reporttype': '2', 'serious': '1', 'seriousnessdeath': '1', 'seriousnesshospitalization': '1', 'receivedateformat': '102', 'receivedate': '20140313', 'receiptdateformat': '102', 'receiptdate': '20140509', 'fulfillexpeditecriteria': '1', 'companynumb': 'CA-ROCHE-1296647', 'duplicate': '1', 'reportduplicate': {'duplicatesource': 'ROCHE', 'duplicatenum
# ...
